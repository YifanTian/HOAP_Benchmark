# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
output_only_n1ql = pd.read_csv('./AQQ_8nodes_round_n1ql_throughput.csv')
output_only_n1ql
# Out:
#    Unnamed: 0  ALL         A0         A1         A2         A4         A8  \
# 0           0   N0   0.000000   0.000000   0.000000   0.000000   0.000000
# 1           1   N1   3.538462   3.491639   3.228969   2.661838   1.917595
# 2           2   N2   6.554875   6.289136   5.891304   5.126949   3.960490
# 3           3   N4  10.781058  10.167131   9.324791   8.273790   5.440642
# 4           4   N8  16.730362  15.247360  14.460468  12.796327   9.388425
# 5           5  N16  23.114143  21.057318  18.852713  16.204558  13.699444
# 6           6  N32  29.314238  27.176863  23.296997  20.121734  16.875691
# 7           7  N64  33.720956  32.413889  24.763041  26.140400  19.673661
#
#          A10
# 0   0.000000
# 1   1.429605
# 2   3.210907
# 3   5.077821
# 4   8.258889
# 5  11.671667
# 6  14.080000
# 7  16.861897

# %%
plt.figure(figsize=(14,12))
idx = 0
label_list = [0,1,2,4,8,10]
for a in [2,3,4,5,6,7]:
    n1ql_list = []
    for i in range(7):
#         print(output_only_n1ql.iloc[i][3])
        n1ql_list.append(output_only_n1ql.iloc[i][a])
        

        
    plt.plot([2**i for i in range(7)], n1ql_list,'-o',label='A=' + str(label_list[idx]))
    idx+=1

plt.ylabel('n1ql throughput n/s',fontsize=24)
plt.xlabel('number of n1ql threads',fontsize=24)
plt.tick_params(labelsize=12)
plt.legend(fontsize = 16)
# plt.savefig('figures/AQQ_n1ql_throughput_vsn.png')

# %%
# plt.figure(figsize=(14,12))
# # for i in range(len(output_only_n1ql)):
# # for i in range(1,4):
# for i in range(1,8):
#     if i == 0:
#         n = 0
#     else:
#         n = 2**(i-1)
#     plt.plot(output_only_n1ql.iloc[i][2:],'-o',label='AQQ N1QL='+str(n))
    
# # for i in range(1,4):
# #     if i == 0:
# #         n = 0
# #     else:
# #         n = 2**(i-1)
# #     plt.plot(connect_n1ql_throughput.iloc[i][2:],'-o',label='AQA NO='+str(n))
   

# plt.ylabel('n1ql throughput n/s',fontsize=24)
# plt.xlabel('number of analytic threads',fontsize=24)
# plt.legend(fontsize=24)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
# plt.savefig('figures/AQQ_n1ql_throughput_vsa.png')

# %%
connect_analytic_throughput = pd.read_csv('./AQQ_8nodes_round_analytic_throughput.csv')
connect_analytic_throughput
# Out:
#    Unnamed: 0  ALL   A0        A1        A2        A4        A8       A10
# 0           0   N0  0.0  0.303337  0.585216  1.114551  2.022806  2.006886
# 1           1   N1  0.0  0.273418  0.540811  0.997984  1.890000  1.877794
# 2           2   N2  0.0  0.265487  0.512048  0.989691  1.827259  1.832061
# 3           3   N4  0.0  0.254103  0.490798  0.936556  1.714286  1.753343
# 4           4   N8  0.0  0.240000  0.459418  0.884146  1.682815  1.680912
# 5           5  N16  0.0  0.218182  0.417910  0.837070  1.604755  1.579717
# 6           6  N32  0.0  0.206693  0.407950  0.784929  1.501502  1.483996
# 7           7  N64  0.0  0.186335  0.390516  0.724711  1.403152  1.442036

# %%
plt.figure(figsize=(14,12))
for i in range(len(connect_analytic_throughput)):
    if i == 0:
        n = 0
    else:
        n = 2**(i-1)
    plt.plot(connect_analytic_throughput.iloc[i][2:],'-o',label=str(n)+' n1ql')
    
plt.ylabel('analytic throughput n/min',fontsize=24)
plt.xlabel('number of analytic threads',fontsize=24)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.savefig('figures/AQQ_analytic_throughput_vsa.png')
# Out:
# (array([-0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,  1.75,
#          2.  ,  2.25]), <a list of 11 Text yticklabel objects>)

# %%
# plt.figure(figsize=(14,12))
# idx = 0
# for a in [3,4,5,6]:
    
#     n1ql_list = []
#     for i in range(7):
#         n = 2**(i-1)
#         n1ql_list.append(connect_analytic_throughput.iloc[i][a])

        
#     plt.plot([2**i for i in range(7)], n1ql_list,label='A=' + str(a-2))

# plt.ylabel('analytic throughput n/s',fontsize=24)
# plt.xlabel('number of n1ql threads',fontsize=24)
# plt.tick_params(labelsize=12)
# plt.ylim([0,0.6])
# plt.legend(fontsize = 16)
# plt.savefig('figures/AQQ_analytic_throughput_vsn.png')

# %%
connect_analytic_throughput = pd.read_csv('./AQQ_8nodes_round_analytic_throughput.csv')
connect_analytic_throughput

plt.figure(figsize=(14,12))
for i in range(len(connect_analytic_throughput)):
    if i == 0:
        n = 0
    else:
        n = 2**(i-1)
    plt.plot(connect_analytic_throughput.iloc[i][2:],'-o',label=str(n)+' n1ql')
    
plt.ylabel('analytic throughput n/min',fontsize=24)
plt.xlabel('number of analytic threads',fontsize=24)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.savefig('figures/AQQ_analytic_throughput_vsa.png')
# Out:
# (array([-0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,  1.75,
#          2.  ,  2.25]), <a list of 11 Text yticklabel objects>)
